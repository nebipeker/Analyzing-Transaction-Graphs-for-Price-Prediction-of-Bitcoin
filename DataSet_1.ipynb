# %%
import pandas as pd
import matplotlib
from matplotlib import pyplot as plt

# %%
data = pd.read_excel('Merged.xlsx').set_index('Date')

# %%
data
# Out:
#             Number Of Transactions  Bitcoin Estimated Transaction Volume  \
# Date
# 2021-10-31                  217435                          50315.367885
# 2021-10-30                  252061                          49018.853138
# 2021-10-29                  305733                         147322.266427
# 2021-10-28                  295558                         112877.273326
# 2021-10-27                  292114                         103462.549306
# ...                            ...                                   ...
# 2013-01-05                   39596                         142274.000000
# 2013-01-04                   38931                         310596.723467
# 2013-01-03                   49926                         215147.000000
# 2013-01-02                   39433                         157983.000000
# 2013-01-01                   38986                         231777.849538
#
#             Bitcoin Cost Per Transaction  \
# Date
# ...

# %%
data["Number Of Transactions"]
# Out:
# Date
# 2021-10-31    217435
# 2021-10-30    252061
# 2021-10-29    305733
# 2021-10-28    295558
# 2021-10-27    292114
#                ...
# 2013-01-05     39596
# 2013-01-04     38931
# 2013-01-03     49926
# 2013-01-02     39433
# 2013-01-01     38986
# Name: Number Of Transactions, Length: 3226, dtype: int64

# %%
plt.figure(figsize = (15, 10))
plt.plot(data["Number Of Transactions"])
plt.xlabel('dates')
plt.title('Number Of Transactions')
plt.show()

# %%
plt.figure(figsize = (15, 10))
plt.plot(data["Bitcoin Estimated Transaction Volume"])
plt.xlabel('dates')
plt.title('Bitcoin Estimated Transaction Volume')
plt.show()

# %%
plt.figure(figsize = (15, 10))
plt.plot(data["Bitcoin Cost Per Transaction"])
plt.xlabel('dates')
plt.title('Bitcoin Cost Per Transaction')
plt.show()

# %%
plt.figure(figsize = (15, 10))
plt.plot(data["Price"])
plt.xlabel('dates')
plt.title('Price')
plt.show()

# %%
plt.figure(figsize = (15, 10))
plt.plot(data["Bitcoin Cost % of Transaction Volume"])
plt.xlabel('dates')
plt.title('Bitcoin Cost % of Transaction Volume')
plt.show()
