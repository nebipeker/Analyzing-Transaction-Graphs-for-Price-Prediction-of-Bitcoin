# %%
import networkx as nx
import pandas as pd
import os
import glob
import csv

# %%
csvs = glob.glob(os.getcwd()+"/data/graphs/*.csv")

# %%
index = 0
for i in csvs:
    print(index ,"/",len(csvs),end="\r")
    index +=1
    df = pd.read_csv(i)
    df.drop("Unnamed: 0",axis=1,inplace=True)
    x = nx.from_pandas_edgelist(df,source="0",target ="1", create_using=nx.DiGraph())
    average_clustering = nx.average_clustering(x)
    density = nx.density(x)
    #average_degree_connectivity = nx.average_degree_connectivity(x)
    number_of_edges = x.number_of_edges()
    number_of_nodes = x.number_of_nodes()
    degree_assortativity_coefficient = nx.degree_assortativity_coefficient(x)
    metrics.append([average_clustering, density, number_of_edges ,number_of_nodes ,degree_assortativity_coefficient])
# Out:
# 95 / 96

# %%
df
# Out:
#     average_clustering   density  number_of_edges  number_of_nodes  \
# 0             0.000437  0.000390             2781             2672
# 1             0.000000  0.000295             3646             3514
# 2             0.000000  0.000509             2219             2088
# 3             0.000178  0.000296             4163             3751
# 4             0.017085  0.000233             4999             4636
# ..                 ...       ...              ...              ...
# 91            0.000018  0.000007            50000            85666
# 92            0.000000  0.000007            50000            87596
# 93            0.000000  0.000006            50000            88050
# 94            0.000000  0.000006            50000            88512
# 95            0.000000  0.000006            50000            89190
#
#     degree_assortativity_coefficient
# 0                          -0.686105
# 1                          -0.591686
# 2                          -0.578755
# 3                          -0.631572
# 4                          -0.661268
# ..                               ...
# 91                          0.025068
# 92                          0.001572
# 93                          0.020592
# 94                         -0.001332
# 95                          0.024188
#
# [96 rows x 5 columns]

# %%
df.to_csv("data/metrics_padlab.csv",index=False)
